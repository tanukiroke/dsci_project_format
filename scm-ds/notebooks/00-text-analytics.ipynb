# %% [markdown]
# ## Dataset containing tweets about Gitlab

# %% [markdown]
# #### Dependencies

# %%
import pandas as pd
import json

# %% [markdown]
# ##### Data

# %%
RAW_DATA = "../data/raw/gitlab_tweets.json"

# %%
df = pd.read_json(open(RAW_DATA))
df.tail(2)
# Out:
#       has_media hashtags img_urls  is_replied  is_reply_to  likes  \
# 2785      False       []       []        True         True     21
# 2786      False       []       []       False        False      2
#
#                             links      parent_tweet_id  replies  \
# 2785                           []  1156995812213215233        1
# 2786  [https://cshort.co/2yulfBV]                             0
#
#                                          reply_to_users  ...  screen_name  \
# 2785  [{'screen_name': 'lessin', 'user_id': '2970511'}]  ...       ilyasu
# 2786                                                 []  ...   ChrisShort
#
#                                                    text  \
# 2785                                             GitLab
# 2786  Recommended Read: How being all-remote helps u...
#
#                                               text_html           timestamp  \
# 2785  <p class="TweetTextSize js-tweet-text tweet-te... 2019-08-01 23:53:25
# ...

# %% [markdown]
# ### Dataframe sorted by timestamp

# %%
df_s = df.sort_values(by = "timestamp", ascending= False)
df_s.head(2)
# Out:
#       has_media                    hashtags img_urls  is_replied  is_reply_to  \
# 1730      False  [gitlab, webcast, webinar]       []       False        False
# 1749      False  [gitlab, webcast, webinar]       []       False        False
#
#       likes                                              links  \
# 1730      1  [https://about.gitlab.com/webcast/adoption-pat...
# 1749      1  [https://about.gitlab.com/webcast/adoption-pat...
#
#      parent_tweet_id  replies reply_to_users  ...   screen_name  \
# 1730                        0             []  ...  hugodazevedo
# 1749                        0             []  ...  hugodazevedo
#
#                                                    text  \
# 1730  Inscrevam-se no webcast da GitLab: Caminhos de...
# 1749  Inscrevam-se no webcast da GitLab: Caminhos de...
#
#                                               text_html           timestamp  \
# 1730  <p class="TweetTextSize js-tweet-text tweet-te... 2020-04-16 23:49:23
# ...

# %% [markdown]
# ### We want to filter tweets based on: Likes, text, timestamp

# %%
df_f = df_s[['likes','text','timestamp']]
df_f.reset_index(inplace=True)
df_f.head(2)
# Out:
#    index  likes                                               text  \
# 0   1730      1  Inscrevam-se no webcast da GitLab: Caminhos de...
# 1   1749      1  Inscrevam-se no webcast da GitLab: Caminhos de...
#
#             timestamp
# 0 2020-04-16 23:49:23
# 1 2020-04-16 23:49:23
